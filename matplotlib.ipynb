# %%
import pandas as pd

# %%
graph = pd.read_csv("D:/8.121.csv")

# %%
graph.head()
# Out:
#          Date  Confirmed cases  Daily growth  Recovered cases  Fatal cases  \
# 0  2021-12-07        267301130      0.260262          8565091      5276422
# 1  2021-12-06        266607252      0.222888          8530476      5268202
# 2  2021-12-05        266014337      0.159650          8502406      5261344
# 3  2021-12-04        265590323      0.191479          8471813      5254145
# 4  2021-12-03        265082746      0.271833          8436631      5248773
#
#    Active cases  Recovery rate  Mortality rate  Affected population  \
# 0     253459617       3.204285        1.973962             3.426938
# 1     252808574       3.199641        1.976016             3.418042
# 2     252250587       3.196221        1.977842             3.410440
# 3     251864365       3.189805        1.978289             3.405004
# 4     251397342       3.182641        1.980051             3.398497
#
#    1 confirmed per every  1 died per every  Confirmed per 1000  Died per 1000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(graph['Date'], graph['Confirmed cases'])

# %%
date = graph['Confirmed cases']
date.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
top_cases = graph[graph["Confirmed cases"]>50000].sort_values("Confirmed cases")
top_cases.plot(x = 'Date', y = ['Confirmed cases','Fatal cases','Active cases'], kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
graph.plot(x="Date", y="Confirmed cases", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Confirmed cases'>

# %%
graph.plot(x="Date", y=["Recovered cases", "Fatal cases", "Active cases"])
plt.show()

# %%
top_cases = graph[graph["Confirmed cases"]>50000].sort_values("Confirmed cases")
top_cases.plot(x = 'Date', y = ['Confirmed cases','Fatal cases','Active cases'], kind='barh')
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
top_cases.plot(x = 'Date', y = ['Confirmed cases','Fatal cases','Active cases'], kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
top_cases.plot(x = 'Date', y = ['Active cases'], kind='box')
# Out:
# <AxesSubplot:>

# %%
top_cases.plot(x = 'Date', y = ['Confirmed cases', 'Active cases'], kind='area')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
top_cases.plot(x = 'Date', y = ['Confirmed cases','Fatal cases','Active cases'], kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>
